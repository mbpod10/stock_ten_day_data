# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
today = datetime.now().strftime("%m-%d-%Y")

# %%
df = pd.read_excel(f'./excel_sheets/10-Day_{today}.xlsx')

# %%
df
# Out:
#     Order Symbol                      Name  Current Price  \
# 0       1   TMUS         T-Mobile U.S. Inc         139.96
# 1       2     PM    Philip Morris Intl Inc         101.23
# 2       3    BMY   Bristol Myers Squibb Co          72.62
# 3       4   MDLZ         Mondelez Intl Inc          66.73
# 4       5    CME           C M E Group Inc         170.08
# ..    ...    ...                       ...            ...
# 79     80   NEPH               Nephros Inc           1.11
# 80     81   GHSI  Guardion Health Sciences           0.15
# 81     82   SINT    Sintx Technologies Inc           9.00
# 82     83   SPRC              Scisparc Ltd           0.76
# 83     84   CELP  Cypress Environ Ptnrs LP           0.03
#
#                Industry Name Ind Group RS  Comp Rating  Market Cap (mil)  \
# 0      Telecom Svcs-Wireless            D           72          174131.8
# 1                    Tobacco           C+           60          156926.9
# 2      Medical-Ethical Drugs            C           79          155062.2
# 3         Food-Confectionery            C           81           91127.7
# 4   Financial Svcs-Specialty           C+           56           61132.9
# ..                       ...          ...          ...               ...
# 79          Medical-Products           B+           10              11.5
# 80  Medical-Research Eqp/Svc           D-           20               9.0
# 81          Medical-Products           B+           14               4.7
# 82    Medical-Biomed/Biotech            A            8               2.3
# 83    Oil&Gas-Field Services           A+            6               0.4
#
#     Vol % Chg vs 50-Day  50-Day Avg Vol (1000s)  ...  Annual Sales (mil)  \
# 0                  24.6                    5539  ...             80118.0
# 1                  17.7                    5007  ...             82223.0
# 2                   7.7                    9236  ...             46385.0
# 3                   0.2                    6076  ...             28720.0
# 4                   4.6                    2139  ...              4689.7
# ..                  ...                     ...  ...                 ...
# 79                -79.4                      30  ...                10.3
# 80                 10.1                     686  ...                 7.2
# 81                -91.3                     541  ...                 0.6
# 82                -97.1                    1197  ...                 0.0
# 83                  0.0                       0  ...               117.3
#
#     Sales Growth 5 Yr  EPS Est Cur Qtr % EPS Est Cur Yr % EPS Est Next Yr %  \
# 0                  19                 -5              -52               228
# 1                   1                 -7               -7                 0
# 2                  23                 -5                6                 5
# 3                   3                 -1                2                 5
# 4                   5                 14               19                 5
# ..                ...                ...              ...               ...
# 79                 24                 30                -                 -
# 80                 93                 95                -                 -
# 81                 37                -67                -                 -
# 82                  -                 57                -                 -
# 83                -14                  -                -                 -
#
#    Yield % P/E  Debt %   PEG Est P/E
# 0      0.0  24   101.3   1.6      21
# 1      5.0  17       -  2.83      18
# 2      3.1   9   110.2  0.41       9
# 3      2.3  23    62.1   3.2      22
# 4      2.4  22    12.6  3.72      20
# ..     ...  ..     ...   ...     ...
# 79     0.0   -     0.8     -       -
# 80     0.0   -       0     -       -
# 81     0.0   -       0     -       -
# 82     0.0   -     0.2     -       -
# 83     0.0   -       0     -       0
#
# [84 rows x 22 columns]

# %%
df['Industry Name'].value_counts()
# Out:
# Banks-Northeast             5
# Medical-Biomed/Biotech      5
# Medical-Products            3
# Finance-Publ Inv Fd-Eqt     3
# Banks-Midwest               3
# Chemicals-Specialty         3
# Finance-Property REIT       3
# Finance-Publ Inv Fd-Bond    2
# Containers/Packaging        2
# Finance-Savings & Loan      2
# Medical-Systems/Equip       2
# Oil&Gas-Drilling            2
# Computer Sftwr-Enterprse    2
# Finance-Mortgage REIT       2
# Real Estate Dvlpmt/Ops      2
# Oil&Gas-Field Services      2
# Elec-Semicondctor Fablss    1
# Media-Radio/Tv              1
# Finance-Publ Inv Fd-Bal     1
# Telecom-Infrastructure      1
# Transportation-Truck        1
# Consumer Prod-Electronic    1
# Retail/Whlsle-Auto Parts    1
# Bldg-Mobile/Mfg & Rv        1
# Computer Sftwr-Gaming       1
# Comml Svcs-Staffing         1
# Computer-Networking         1
# Medical-Services            1
# Mining-Gold/Silver/Gems     1
# Insurance-Prop/Cas/Titl     1
# Steel-Producers             1
# Telecom Svcs-Wireless       1
# Retail-Internet             1
# Media-Books                 1
# Computer Sftwr-Financial    1
# Medical-Ethical Drugs       1
# Food-Confectionery          1
# Financial Svcs-Specialty    1
# Cosmetics/Personal Care     1
# Utility-Diversified         1
# Retail-Restaurants          1
# Banks-Southeast             1
# Retail-Leisure Products     1
# Computer Sftwr-Design       1
# Bldg-A/C & Heating Prds     1
# Internet-Content            1
# Energy-Alternative/Other    1
# Metal Proc & Fabrication    1
# Comp Sftwr-Spec Enterprs    1
# Utility-Gas Distribution    1
# Computer Sftwr-Security     1
# Comml Svcs-Leasing          1
# Bldg-Constr Prds/Misc       1
# Security/Sfty               1
# Tobacco                     1
# Retail-Super/Mini Mkts      1
# Medical-Research Eqp/Svc    1
# Name: Industry Name, dtype: int64

# %%
df[(df['Industry Name'] == 'Medical-Biomed/Biotech') | (df['Industry Name'] == 'Finance-Publ Inv Fd-Eqt')]
# Out:
#     Order Symbol                      Name  Current Price  \
# 31     32   AMLX    Amylyx Pharmaceuticals          35.54
# 39     40    GAB  Gabelli Equity Trust Inc           5.52
# 51     52    SVA       Sinovac Biotech Ltd           6.47
# 52     53    BST    Blackrock Science Tech          28.79
# 57     58   AVEO      Aveo Pharmaceuticals          14.94
# 72     73   RVLP   Rvl Pharmaceuticals plc           1.13
# 75     76    TPZ   Tortoise Pwr & Enrgy Fd          12.68
# 82     83   SPRC              Scisparc Ltd           0.76
#
#               Industry Name Ind Group RS  Comp Rating  Market Cap (mil)  \
# 31   Medical-Biomed/Biotech            A           61            2354.7
# 39  Finance-Publ Inv Fd-Eqt           D+            0            1610.7
# 51   Medical-Biomed/Biotech            A           79             737.7
# 52  Finance-Publ Inv Fd-Eqt           D+            0             727.1
# 57   Medical-Biomed/Biotech            A           94             519.4
# 72   Medical-Biomed/Biotech            A           37             112.0
# 75  Finance-Publ Inv Fd-Eqt           D+            0              82.7
# 82   Medical-Biomed/Biotech            A            8               2.3
#
#     Vol % Chg vs 50-Day  50-Day Avg Vol (1000s)  ...  Annual Sales (mil)  \
# 31                 33.8                     762  ...                 0.3
# 39                -39.5                     453  ...                 0.0
# 51                  0.0                       0  ...             19374.9
# 52                -11.2                     163  ...                 0.0
# 57                -11.1                     707  ...                42.3
# 72                -72.8                      75  ...                17.5
# 75                -36.8                      19  ...                 0.0
# 82                -97.1                    1197  ...                 0.0
#
#     Sales Growth 5 Yr  EPS Est Cur Qtr % EPS Est Cur Yr % EPS Est Next Yr %  \
# 31                -44                -68                -                 -
# 39                  -                  -                -                 -
# 51                177                  -                -                 -
# 52                  -                  -                -                 -
# 57                 61                 71                -                 -
# 72                -44                 29                -                 -
# 75                  -                  -                -                 -
# 82                  -                 57                -                 -
#
#    Yield % P/E  Debt % PEG Est P/E
# 31     0.0   -       0   -       -
# 39    10.9   -       -   -       -
# 51     0.0   0     0.3   0       -
# 52    10.4   -       -   -       -
# 57     0.0   -    82.8   -      35
# 72     0.0   -    57.1   -       -
# 75     9.9   -       -   -       -
# 82     0.0   -     0.2   -       -
#
# [8 rows x 22 columns]
