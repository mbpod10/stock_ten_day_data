# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
today = datetime.now().strftime("%m-%d-%Y")

# %%
df = pd.read_excel(f'./excel_sheets/10-Day_{today}.xlsx')

# %%
df
# Out:
#      Order Symbol                      Name  Current Price  \
# 0        1   MSFT            Microsoft Corp         239.58
# 1        2    CAT           Caterpillar Inc         238.88
# 2        3   SONY       Sony Group Corp Ads          76.65
# 3        4    MET               Metlife Inc          72.15
# 4        5    AIG       American Intl Group          62.93
# ..     ...    ...                       ...            ...
# 103    104     ID         Parts Id Inc Cl A           0.98
# 104    105   SALM    Salem Media Group Cl A           1.04
# 105    106    PMD         Psychemedics Corp           4.93
# 106    107    CKX           C K X Lands Inc          10.02
# 107    108   CELP  Cypress Environ Ptnrs LP           0.03
#
#                Industry Name Ind Group RS  Comp Rating  Market Cap (mil)  \
# 0     Computer Sftwr-Desktop           D-           58         1785942.6
# 1    Machinery-Constr/Mining           A+           98          124315.3
# ...

# %%
df['Industry Name'].value_counts()
# Out:
# Medical-Biomed/Biotech      7
# Finance-Publ Inv Fd-Eqt     7
# Real Estate Dvlpmt/Ops      4
# Finance-Property REIT       3
# Computer Sftwr-Medical      3
#                            ..
# Machinery-Constr/Mining     1
# Hsehold-Appliances/Wares    1
# Office Supplies Mfg         1
# Media-Books                 1
# Media-Radio/Tv              1
# Name: Industry Name, Length: 74, dtype: int64

# %%
df[(df['Industry Name'] == 'Medical-Biomed/Biotech') | (df['Industry Name'] == 'Finance-Publ Inv Fd-Eqt')]
# Out:
#      Order Symbol                      Name  Current Price  \
# 37      38   MYOV      Myovant Sciences Ltd          26.93
# 47      48   DICE     Dice Therapeutics Inc          31.33
# 54      55    NFJ  Virtus Div Int Prem Strt          11.23
# 57      58    FPF  First Tr Int Dur Pf Incm          17.03
# 58      59    GAM  General American Invstrs          35.98
# 64      65    SVA       Sinovac Biotech Ltd           6.47
# 68      69    CCD    Calamos Dyn Conv & Inc          20.61
# 74      75   TARS    Tarsus Pharmaceuticals          14.42
# 81      82   PDSB    Pds Biotechnology Corp          10.62
# 82      83   NPCT   Nuveen Core Plus Impact          10.46
# 91      92    IGA  Voya Glb Adv and Prem Op           8.83
# 95      96   OPNT    Opiant Pharmaceuticals          20.24
# 99     100    MFD  Macquarie Fst Tr Glb Inf           8.14
# 101    102   SNSE    Sensei Biotherapeutics           1.44
#
#                Industry Name Ind Group RS  Comp Rating  Market Cap (mil)  \
# ...

# %%
df[df['Industry Name'] == 'Finance-Publ Inv Fd-Eqt']
# Out:
#     Order Symbol                      Name  Current Price  \
# 54     55    NFJ  Virtus Div Int Prem Strt          11.23
# 57     58    FPF  First Tr Int Dur Pf Incm          17.03
# 58     59    GAM  General American Invstrs          35.98
# 68     69    CCD    Calamos Dyn Conv & Inc          20.61
# 82     83   NPCT   Nuveen Core Plus Impact          10.46
# 91     92    IGA  Voya Glb Adv and Prem Op           8.83
# 99    100    MFD  Macquarie Fst Tr Glb Inf           8.14
#
#               Industry Name Ind Group RS  Comp Rating  Market Cap (mil)  \
# 54  Finance-Publ Inv Fd-Eqt           D+            0            1064.6
# 57  Finance-Publ Inv Fd-Eqt           D+            0            1036.2
# 58  Finance-Publ Inv Fd-Eqt           D+            0             860.7
# 68  Finance-Publ Inv Fd-Eqt           D+            0             531.7
# 82  Finance-Publ Inv Fd-Eqt           D+            0             300.8
# ...
